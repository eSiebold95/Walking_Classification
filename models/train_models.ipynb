# %%
import pandas as pd
import numpy as np
import train_models as tm

# %%
### create an instance of the ModelTrainer class
trainer = tm.ModelTrainer(random_state=42, n_cross_validation=5, data_type = ['fft', 'raw'], rnds_hp_tuning=50, quick_mode=False) # set test_split, random_state, n_cross_val, type of data as needed
# load data
trainer.load_csvs()

# %%
print(f'shape of lab data: {pd.concat(trainer.fft_lab_data, ignore_index=True).shape}')
print(f'shape of field data: {pd.concat(trainer.fft_field_data, ignore_index=True).shape}')

# %%
trainer.training_loop()

# %%
trainer.save_results("results/results")
