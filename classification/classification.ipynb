# %%
import field_classification as field_classification
import lab_classification as lab_classification
import unify as unify
import os

# %%
# unify lab participant data
unify.Unify()
# Out:
# Processing participant: PS01
# Unified file created: /home/elias/2025/sshfs_mounter_2025/data_elias/Lab_data/model_labeled_data/unified/PS01.csv
# Processing participant: PS03
# Single file created: /home/elias/2025/sshfs_mounter_2025/data_elias/Lab_data/model_labeled_data/unified/PS02.csv
# Processing participant: PS04
# Single file created: /home/elias/2025/sshfs_mounter_2025/data_elias/Lab_data/model_labeled_data/unified/PS03.csv
# Processing participant: PS05
# Single file created: /home/elias/2025/sshfs_mounter_2025/data_elias/Lab_data/model_labeled_data/unified/PS04.csv
# Processing participant: PS06
# Unified file created: /home/elias/2025/sshfs_mounter_2025/data_elias/Lab_data/model_labeled_data/unified/PS05.csv
# Processing participant: PS08
# Single file created: /home/elias/2025/sshfs_mounter_2025/data_elias/Lab_data/model_labeled_data/unified/PS06.csv
# Processing participant: PS09
# Single file created: /home/elias/2025/sshfs_mounter_2025/data_elias/Lab_data/model_labeled_data/unified/PS07.csv
# Processing participant: PS10
# Single file created: /home/elias/2025/sshfs_mounter_2025/data_elias/Lab_data/model_labeled_data/unified/PS08.csv
# Processing participant: PS11
# Unified file created: /home/elias/2025/sshfs_mounter_2025/data_elias/Lab_data/model_labeled_data/unified/PS09.csv
# Processing participant: PS13
# Unified file created: /home/elias/2025/sshfs_mounter_2025/data_elias/Lab_data/model_labeled_data/unified/PS10.csv
# Processing participant: PS15
# Unified file created: /home/elias/2025/sshfs_mounter_2025/data_elias/Lab_data/model_labeled_data/unified/PS11.csv
# Processing participant: PS17
# Single file created: /home/elias/2025/sshfs_mounter_2025/data_elias/Lab_data/model_labeled_data/unified/PS12.csv
# Processing participant: PS18
# Single file created: /home/elias/2025/sshfs_mounter_2025/data_elias/Lab_data/model_labeled_data/unified/PS13.csv
# Processing participant: PS19
# Single file created: /home/elias/2025/sshfs_mounter_2025/data_elias/Lab_data/model_labeled_data/unified/PS14.csv
# Processing participant: PS20
# Single file created: /home/elias/2025/sshfs_mounter_2025/data_elias/Lab_data/model_labeled_data/unified/PS15.csv
# Processing participant: PS21
# Single file created: /home/elias/2025/sshfs_mounter_2025/data_elias/Lab_data/model_labeled_data/unified/PS16.csv
# Processing participant: PS22
# Unified file created: /home/elias/2025/sshfs_mounter_2025/data_elias/Lab_data/model_labeled_data/unified/PS17.csv
# Processing participant: PS24
# Unified file created: /home/elias/2025/sshfs_mounter_2025/data_elias/Lab_data/model_labeled_data/unified/PS18.csv
# Processing participant: PS26
# Single file created: /home/elias/2025/sshfs_mounter_2025/data_elias/Lab_data/model_labeled_data/unified/PS19.csv

# %%
root_dir = '/data/march/sshfs_mounter_march_2025/station_march_2025'
watch_dir = '/data/march/sshfs_mounter_march_2025/data_elias/watch_data'
output_raw = "/home/elias/2025/sshfs_mounter_2025/data_elias/ECSS_2026/raw_field"
output_fft = "/home/elias/2025/sshfs_mounter_2025/data_elias/ECSS_2026/fft_field"

# %%
participants = sorted(os.listdir(root_dir))

for part in participants:
    if part.endswith('.tgz'):
        continue
    else:
        instance = field_classification.FieldClassifier(root_dir, watch_dir, part, output_fft, output_raw, hour_offset=1)
# Out:
# Initializing FieldClassifier for SM001... data read (1.89 s)... data classified (2.01 s)... data windowed (2.01 s)... data merged (8.29 s)... data FFT applied (9.50 s).
# Initializing FieldClassifier for SM002... data read (1.75 s)... data classified (1.86 s)... data windowed (1.86 s)... data merged (8.21 s)... data FFT applied (9.42 s).
# Initializing FieldClassifier for SM003... data read (1.35 s)... data classified (1.43 s)... data windowed (1.43 s)... data merged (7.58 s)... data FFT applied (8.76 s).
# Initializing FieldClassifier for SM004... data read (0.93 s)... data classified (0.99 s)... data windowed (1.00 s)... data merged (6.41 s)... data FFT applied (7.45 s).
# Initializing FieldClassifier for SM006... data read (0.98 s)... data classified (1.06 s)... data windowed (1.06 s)... data merged (6.94 s)... data FFT applied (8.05 s).
# Initializing FieldClassifier for SM007... data read (1.06 s)... data classified (1.13 s)... data windowed (1.14 s)... data merged (6.47 s)... data FFT applied (7.50 s).
# Initializing FieldClassifier for SM008... data read (0.76 s)... data classified (0.82 s)... data windowed (0.82 s)... data merged (4.78 s)... data FFT applied (5.61 s).
# Initializing FieldClassifier for SM009... data read (0.96 s)... data classified (1.04 s)... data windowed (1.05 s)... data merged (6.91 s)... data FFT applied (8.01 s).
# Initializing FieldClassifier for SM010... data read (1.15 s)... data classified (1.24 s)... data windowed (1.24 s)... data merged (6.62 s)... data FFT applied (7.66 s).
# Initializing FieldClassifier for SM011... data read (1.10 s)... data classified (1.20 s)... data windowed (1.20 s)... data merged (7.57 s)... data FFT applied (8.92 s).
# Initializing FieldClassifier for SM012... data read (1.10 s)... data classified (1.19 s)... data windowed (1.20 s)... data merged (7.27 s)... data FFT applied (8.50 s).
# Initializing FieldClassifier for SM013... data read (1.00 s)... data classified (1.10 s)... data windowed (1.10 s)... data merged (6.92 s)... data FFT applied (8.07 s).
# Initializing FieldClassifier for SM014... data read (0.83 s)... data classified (0.90 s)... data windowed (0.90 s)... data merged (5.27 s)... data FFT applied (6.09 s).
# Initializing FieldClassifier for SM015... data read (0.80 s)... data classified (0.87 s)... data windowed (0.87 s)... data merged (5.46 s)... data FFT applied (6.30 s).
# Initializing FieldClassifier for SM016... data read (1.05 s)... data classified (1.14 s)... data windowed (1.14 s)... data merged (6.76 s)... data FFT applied (7.83 s).
# Initializing FieldClassifier for SM017... data read (1.10 s)... data classified (1.19 s)... data windowed (1.19 s)... data merged (7.45 s)... data FFT applied (8.63 s).
# Initializing FieldClassifier for SM018... data read (0.95 s)... data classified (1.02 s)... data windowed (1.03 s)... data merged (7.13 s)... data FFT applied (8.30 s).
# Initializing FieldClassifier for SM019... data read (0.87 s)... data classified (0.95 s)... data windowed (0.96 s)... data merged (6.95 s)... data FFT applied (8.08 s).
# Initializing FieldClassifier for SM020... data read (0.92 s)... data classified (1.01 s)... data windowed (1.02 s)... data merged (7.06 s)... data FFT applied (8.21 s).
# Initializing FieldClassifier for SM021... data read (0.61 s)... data classified (0.68 s)... data windowed (0.68 s)... data merged (4.99 s)... data FFT applied (5.73 s).
# Initializing FieldClassifier for SM022... data read (0.94 s)... data classified (1.04 s)... data windowed (1.04 s)... data merged (7.11 s)... data FFT applied (8.25 s).
# Initializing FieldClassifier for SM023... data read (1.17 s)... data classified (1.27 s)... data windowed (1.27 s)... data merged (7.33 s)... data FFT applied (8.49 s).
# Initializing FieldClassifier for SM024...
# /opt/code/physiological-studies/playground_Elias/ECSS_2026/classification/field_classification.py:75: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.df_watch = pd.read_csv(os.path.join(root_dir_gps, self.id + '.csv'))
# data read (0.30 s)... data classified (0.31 s)... data windowed (0.31 s)... data merged (0.32 s)... data FFT applied (0.32 s).
# Initializing FieldClassifier for SM025... data read (1.00 s)... data classified (1.09 s)... data windowed (1.10 s)... data merged (6.77 s)... data FFT applied (7.87 s).
# Initializing FieldClassifier for SM026... data read (0.43 s)... data classified (0.45 s)... data windowed (0.45 s)... data merged (1.72 s)... data FFT applied (1.95 s).

# %%
root_dir = "/home/elias/2025/sshfs_mounter_2025/data_elias/Lab_data/model_labeled_data/unified"
output_raw = "/home/elias/2025/sshfs_mounter_2025/data_elias/ECSS_2026/raw_lab"
output_fft = "/home/elias/2025/sshfs_mounter_2025/data_elias/ECSS_2026/fft_lab"

# %%
participants = sorted(os.listdir(root_dir))

for part in participants:
    instance = lab_classification.LabClassifier(root_dir, output_raw, output_fft, part)
# Out:
# data read for PS01.csv... data reshaped... labels checked... fft performed... data saved.
# data read for PS02.csv... data reshaped... labels checked... fft performed... data saved.
# data read for PS03.csv... data reshaped... labels checked... fft performed... data saved.
# data read for PS04.csv... data reshaped... labels checked... fft performed... data saved.
# data read for PS05.csv... data reshaped... labels checked... fft performed... data saved.
# data read for PS06.csv... data reshaped... labels checked... fft performed... data saved.
# data read for PS07.csv... data reshaped... labels checked... fft performed... data saved.
# data read for PS08.csv... data reshaped... labels checked... fft performed... data saved.
# data read for PS09.csv... data reshaped... labels checked... fft performed... data saved.
# data read for PS10.csv... data reshaped... labels checked... fft performed... data saved.
# data read for PS11.csv... data reshaped... labels checked... fft performed... data saved.
# data read for PS12.csv... data reshaped... labels checked... fft performed... data saved.
# data read for PS13.csv... data reshaped... labels checked... fft performed... data saved.
# data read for PS14.csv... data reshaped... labels checked... fft performed... data saved.
# data read for PS15.csv... data reshaped... labels checked... fft performed... data saved.
# data read for PS16.csv... data reshaped... labels checked... fft performed... data saved.
# data read for PS17.csv... data reshaped... labels checked... fft performed... data saved.
# data read for PS18.csv... data reshaped... labels checked... fft performed... data saved.
# data read for PS19.csv... data reshaped... labels checked... fft performed... data saved.
